# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1346: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.171222
# Nearest to most: honours, carmelite, prompting, hummers, matra, gradient, custis, annabel,
# Nearest to also: sheet, bonn, rigoletto, interacting, generalitat, monarchy, margaret, rainforests,
# Nearest to their: mugwort, licences, parliamentary, nafta, dana, vascular, diger, garbage,
# Nearest to UNK: collar, explainable, cleaner, accrued, honouring, acacias, mutated, bowie,
# Nearest to seven: brazil, manipulative, alleviated, vav, apprehended, sweetened, sunt, ho,
# Nearest to have: positively, tristan, leopard, telstra, market, airway, costello, coma,
# Nearest to had: gomer, rowling, missions, maltese, rakyat, insoluble, relegated, panentheism,
# Nearest to united: lasi, merging, sanders, foxe, une, militaristic, assyria, pledging,
# Nearest to known: told, trapdoor, frigates, kama, playoff, cairn, ecoregion, widdecombe,
# Nearest to more: wanting, creditor, brighter, amigaone, alemanni, fin, crushing, kuiper,
# Nearest to during: verbose, augustinians, fethry, koestler, sava, drops, speleological, assessment,
# Nearest to and: label, criminally, pons, gte, thracians, transporter, cotswold, elfman,
# Nearest to b: evaluates, precludes, organisational, pnp, humanitarian, voting, noticed, glues,
# Nearest to five: whipple, ferreira, none, chordata, antenna, herndon, prototypical, shillings,
# Nearest to a: gift, posthuman, mato, unpaired, glide, gunned, adventurers, harbours,
# Nearest to people: worshipper, gale, bile, grade, interests, outboard, avengers, nazareth,
# Average loss at step 2000: 4.374085
# Average loss at step 4000: 3.863025
# Average loss at step 6000: 3.791740
# Average loss at step 8000: 3.689637
# Average loss at step 10000: 3.614547
# Nearest to most: honours, era, carmelite, abc, abugidas, beryllium, haryana, toward,
# Nearest to also: often, neorealism, sometimes, not, it, who, which, noise,
# Nearest to their: its, his, the, licences, parliamentary, fptp, grew, adder,
# Nearest to UNK: slayer, klingon, badajoz, m, noonan, rhapsody, amphetamine, fox,
# Nearest to seven: six, eight, nine, five, three, four, zero, two,
# Nearest to have: had, be, has, are, were, quizzes, modifiers, positively,
# Nearest to had: have, was, has, were, been, postmodernists, rakyat, helped,
# Nearest to united: significand, triangulation, sanders, iphigenia, gyre, moabites, une, habits,
# Nearest to known: egyptians, ajaccio, scheme, playoff, matilda, inuit, told, mouthpiece,
# Nearest to more: less, creditor, emotions, wanting, larger, bannerman, engraving, brighter,
# Nearest to during: at, isostatic, filippo, canes, anonymity, llewellyn, best, unpublished,
# Nearest to and: or, arable, landings, but, in, of, sor, s,
# Nearest to b: d, evaluates, humanitarian, italian, varro, vw, polyphyletic, inflating,
# Nearest to five: six, eight, four, three, seven, nine, two, zero,
# Nearest to a: the, poul, mikvah, this, josaphat, anomaly, dhaka, hysterical,
# Nearest to people: worshipper, gale, laissez, stratigraphy, alison, unwittingly, bile, prepare,
# Average loss at step 12000: 3.601854
# Average loss at step 14000: 3.569005
# Average loss at step 16000: 3.408835
# Average loss at step 18000: 3.458971
# Average loss at step 20000: 3.540307
# Nearest to most: some, honours, era, carmelite, more, toward, many, teaches,
# Nearest to also: often, which, now, sometimes, not, who, neorealism, there,
# Nearest to their: his, its, the, her, our, some, schwenkfeld, any,
# Nearest to UNK: troublesome, conforming, j, representable, comprehensive, fellowships, labored, arctocephalus,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to have: had, has, were, be, are, quizzes, kankan, modifiers,
# Nearest to had: has, have, were, was, postmodernists, been, limes, helped,
# Nearest to united: significand, triangulation, city, repubblica, iphigenia, origins, moabites, une,
# Nearest to known: such, used, scheme, playoff, egyptians, inuit, aaa, murphy,
# Nearest to more: less, very, most, larger, corporate, emotions, footlights, iron,
# Nearest to during: at, under, in, after, since, anonymity, best, eighties,
# Nearest to and: or, but, in, processing, for, who, at, rinzai,
# Nearest to b: d, khoi, inflating, italian, vw, bolstering, hogarth, polydor,
# Nearest to five: six, seven, four, eight, three, two, zero, nine,
# Nearest to a: the, this, golf, dhaka, any, no, gift, chord,
# Nearest to people: alison, laissez, worshipper, spain, other, zur, deficiencies, homegrown,
# Average loss at step 22000: 3.501805
# Average loss at step 24000: 3.489624
# Average loss at step 26000: 3.482386
# Average loss at step 28000: 3.476981
# Average loss at step 30000: 3.507111
# Nearest to most: some, honours, many, more, toward, teaches, arousing, abc,
# Nearest to also: often, now, which, still, who, sometimes, below, never,
# Nearest to their: its, his, the, her, some, our, many, these,
# Nearest to UNK: http, leakey, latinus, enraged, bengali, galesburg, h, la,
# Nearest to seven: eight, four, six, five, nine, three, zero, one,
# Nearest to have: had, has, are, were, be, kankan, senseless, helped,
# Nearest to had: has, have, was, were, postmodernists, limes, when, helped,
# Nearest to united: significand, triangulation, myung, iphigenia, city, repubblica, une, origins,
# Nearest to known: used, such, well, aaa, murphy, playoff, inuit, scheme,
# Nearest to more: less, very, larger, rather, most, emotions, outpatient, iron,
# Nearest to during: after, in, at, when, under, since, through, canes,
# Nearest to and: or, but, in, s, rita, landings, tigris, aged,
# Nearest to b: d, polydor, vw, typographical, italian, sparsely, bolstering, khoi,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to a: the, poul, no, dhaka, any, hysterical, heraclitus, another,
# Nearest to people: jews, laissez, stratigraphy, zur, condorcet, homegrown, alison, algeria,
# Average loss at step 32000: 3.503118
# Average loss at step 34000: 3.496137
# Average loss at step 36000: 3.455345
# Average loss at step 38000: 3.302314
# Average loss at step 40000: 3.426116
# Nearest to most: more, many, honours, carmelite, some, toward, sandhi, teaches,
# Nearest to also: often, still, which, sometimes, there, who, now, commonly,
# Nearest to their: its, his, her, the, our, some, other, these,
# Nearest to UNK: b, j, offline, spreads, les, klingon, silhouette, poodle,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to have: had, has, were, are, be, include, senseless, pictorial,
# Nearest to had: has, have, was, were, already, having, orientations, helped,
# Nearest to united: significand, triangulation, repubblica, city, cavelier, iphigenia, une, myung,
# Nearest to known: used, such, aaa, well, seen, comparatively, considered, playoff,
# Nearest to more: less, most, very, rather, lazenby, larger, meher, behave,
# Nearest to during: at, after, since, on, when, under, in, before,
# Nearest to and: or, but, in, including, parable, strains, s, residences,
# Nearest to b: d, c, UNK, polydor, f, e, g, universala,
# Nearest to five: six, seven, four, three, eight, zero, nine, two,
# Nearest to a: the, another, or, any, no, gift, ndez, fuller,
# Nearest to people: stratigraphy, those, condorcet, astute, jews, algeria, laissez, wishing,
# Average loss at step 42000: 3.435334
# Average loss at step 44000: 3.454711
# Average loss at step 46000: 3.449273
# Average loss at step 48000: 3.355124
# Average loss at step 50000: 3.383358
# Nearest to most: more, some, many, both, sandhi, less, honours, erickson,
# Nearest to also: still, which, often, now, who, actually, sometimes, greeks,
# Nearest to their: his, its, her, the, our, your, these, some,
# Nearest to UNK: rebellious, meteora, et, insecure, porpoise, http, diligent, j,
# Nearest to seven: eight, six, four, nine, five, three, one, zero,
# Nearest to have: had, has, be, were, are, kitty, pictorial, quizzes,
# Nearest to had: has, have, was, were, having, since, when, already,
# Nearest to united: significand, cavelier, triangulation, constitution, repubblica, une, iphigenia, city,
# Nearest to known: used, such, possible, available, viewed, comparatively, regarded, ajaccio,
# Nearest to more: less, most, rather, very, larger, behave, lazenby, highly,
# Nearest to during: after, in, at, under, when, since, within, through,
# Nearest to and: or, but, including, however, while, in, macrolides, muentzer,
# Nearest to b: d, c, f, r, polydor, e, mourning, histogram,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to a: the, any, tamias, hysterical, josaphat, another, anomaly, gonads,
# Nearest to people: men, jews, laissez, scholars, trident, cases, words, zur,
# Average loss at step 52000: 3.435037
# Average loss at step 54000: 3.427076
# Average loss at step 56000: 3.441513
# Average loss at step 58000: 3.396002
# Average loss at step 60000: 3.395659
# Nearest to most: many, more, some, less, sandhi, teaches, honours, response,
# Nearest to also: now, still, often, which, who, actually, there, commonly,
# Nearest to their: its, his, her, our, the, your, whose, these,
# Nearest to UNK: launcher, rebellious, http, crackdown, leucippus, comprehensive, leakey, bhopal,
# Nearest to seven: six, eight, four, nine, five, three, zero, two,
# Nearest to have: had, has, are, were, be, choose, having, quizzes,
# Nearest to had: has, have, was, having, were, postmodernists, been, yet,
# Nearest to united: significand, constitution, cavelier, repubblica, epinephrine, triangulation, myung, jerome,
# Nearest to known: used, such, defined, possible, considered, comparatively, available, famous,
# Nearest to more: less, rather, very, most, larger, lazenby, quite, behave,
# Nearest to during: after, before, although, when, in, at, throughout, since,
# Nearest to and: or, but, including, than, overzealous, however, hieroglyphic, aged,
# Nearest to b: d, c, f, r, polydor, n, m, chittagong,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to a: the, another, any, every, pruning, unpaired, no, dhaka,
# Nearest to people: men, scholars, jews, those, homegrown, condorcet, stratification, words,
# Average loss at step 62000: 3.238591
# Average loss at step 64000: 3.252151
# Average loss at step 66000: 3.404925
# Average loss at step 68000: 3.396310
# Average loss at step 70000: 3.358256
# Nearest to most: more, less, many, sandhi, some, virgo, both, all,
# Nearest to also: often, now, still, which, commonly, below, there, actually,
# Nearest to their: its, his, her, the, our, your, some, whose,
# Nearest to UNK: noor, leakey, ver, journalist, quarterback, scribner, gutenberg, et,
# Nearest to seven: six, eight, four, nine, five, three, zero, two,
# Nearest to have: had, has, were, are, be, include, having, maintain,
# Nearest to had: has, have, was, were, having, postmodernists, been, won,
# Nearest to united: significand, cavelier, constitution, epinephrine, myung, triangulation, plucking, repubblica,
# Nearest to known: used, such, defined, viewed, regarded, seen, famous, comparatively,
# Nearest to more: less, most, rather, very, larger, too, quite, lazenby,
# Nearest to during: after, before, throughout, within, in, under, through, despite,
# Nearest to and: or, but, however, than, overzealous, which, while, of,
# Nearest to b: d, f, r, polydor, c, n, professors, fichte,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to a: another, the, any, hysterical, rulership, wolverine, chicagoans, each,
# Nearest to people: men, scholars, forged, ambiguously, jews, words, historians, cases,
# Average loss at step 72000: 3.374573
# Average loss at step 74000: 3.344708
# Average loss at step 76000: 3.323909
# Average loss at step 78000: 3.355697
# Average loss at step 80000: 3.380823
# Nearest to most: many, more, some, virgo, less, sandhi, especially, all,
# Nearest to also: now, still, often, which, commonly, indo, subsequently, plectrum,
# Nearest to their: its, his, her, your, our, whose, both, the,
# Nearest to UNK: crm, dr, franca, physicist, leakey, l, davis, hiram,
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Nearest to have: had, has, be, are, were, include, having, macleod,
# Nearest to had: has, have, was, were, having, postmodernists, been, helped,
# Nearest to united: significand, constitution, cavelier, epinephrine, jerome, myung, plucking, iphigenia,
# Nearest to known: used, defined, such, viewed, regarded, seen, possible, available,
# Nearest to more: less, very, rather, most, quite, larger, lazenby, extremely,
# Nearest to during: after, before, when, throughout, in, despite, at, through,
# Nearest to and: or, but, including, rita, macrolides, while, than, un,
# Nearest to b: d, c, r, polydor, mixes, f, citation, kipper,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to a: another, the, flyby, hysterical, tamias, durkheim, kapellmeister, provable,
# Nearest to people: men, words, scholars, children, historians, persons, jews, symptom,
# Average loss at step 82000: 3.410972
# Average loss at step 84000: 3.410042
# Average loss at step 86000: 3.389494
# Average loss at step 88000: 3.355558
# Average loss at step 90000: 3.363430
# Nearest to most: many, more, virgo, some, less, scandinavians, among, honours,
# Nearest to also: still, now, which, often, commonly, actually, generally, subsequently,
# Nearest to their: its, his, her, your, our, whose, the, rage,
# Nearest to UNK: sir, scribner, kemp, leakey, peaches, et, randori, les,
# Nearest to seven: eight, four, five, nine, six, three, one, zero,
# Nearest to have: had, has, were, be, are, having, quizzes, remain,
# Nearest to had: has, have, was, were, having, since, never, began,
# Nearest to united: constitution, cavelier, significand, epinephrine, jerome, triangulation, myung, verrocchio,
# Nearest to known: such, used, defined, regarded, viewed, possible, opposed, available,
# Nearest to more: less, rather, very, most, too, larger, quite, better,
# Nearest to during: in, after, despite, at, before, within, throughout, when,
# Nearest to and: or, but, including, while, hydrodynamics, rita, romany, dermatology,
# Nearest to b: d, r, f, kipper, c, polydor, g, vw,
# Nearest to five: eight, four, seven, three, nine, six, zero, two,
# Nearest to a: another, the, hysterical, any, every, americanized, flyby, golf,
# Nearest to people: men, children, students, ambiguously, soldiers, jews, scholars, astor,
# Average loss at step 92000: 3.402372
# Average loss at step 94000: 3.258629
# Average loss at step 96000: 3.357202
# Average loss at step 98000: 3.243193
# Average loss at step 100000: 3.357310
# Nearest to most: more, less, especially, many, virgo, natives, some, emoticons,
# Nearest to also: still, now, actually, often, commonly, which, subsequently, never,
# Nearest to their: its, his, her, our, your, the, pumping, some,
# Nearest to UNK: http, et, liza, crm, leakey, fenton, waterproof, les,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to have: had, has, were, are, contain, include, be, having,
# Nearest to had: has, have, having, since, was, were, helped, is,
# Nearest to united: cavelier, constitution, significand, epinephrine, myung, triangulation, jerome, plucking,
# Nearest to known: defined, such, possible, regarded, used, viewed, opposed, available,
# Nearest to more: less, most, very, rather, larger, better, lazenby, extremely,
# Nearest to during: in, after, within, throughout, despite, before, when, at,
# Nearest to and: but, or, however, including, while, although, when, like,
# Nearest to b: d, c, meadows, english, french, jmu, vividly, jesse,
# Nearest to five: seven, four, six, eight, three, zero, nine, two,
# Nearest to a: another, any, the, hysterical, unpaired, pruning, americanized, scientologists,
# Nearest to people: men, children, students, jews, words, persons, astor, countries,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
#skip_window = 1 # How many words to consider left and right.
#num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 #How many words to consider on left and right
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, 
                               inputs=tf.reduce_sum(embed,1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 10000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 50000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.807506
# Nearest to have: allusion, kart, biscay, teachings, philistines, sketch, methadone, thirdly,
# Nearest to after: byrd, mountaineer, bnetd, equating, cauldron, hideo, gchq, pawns,
# Nearest to s: smallville, aoe, lactam, describe, dakini, rigging, scandinavia, powerbook,
# Nearest to many: uncircumcised, cardoso, instant, zechariah, parsers, dons, serialized, twickenham,
# Nearest to all: repudiating, voronin, hafez, durability, essex, cosmos, incongruous, passionately,
# Nearest to state: couple, overwhelms, rtp, electroacoustic, za, highest, rodrigues, inundated,
# Nearest to during: natasha, gayle, preterist, amx, byproduct, heterogeneous, connection, virginity,
# Nearest to it: refracted, overlapped, speyer, terse, nathanael, pygmalion, booted, squeezed,
# Nearest to however: serialism, thirtieth, nikki, hampton, acts, mnemonics, inns, dari,
# Nearest to world: catwoman, seafarers, exclaimed, ko, scavullo, granada, congenital, presumably,
# Nearest to he: nunn, lutheran, looking, polytheism, tithes, campaigning, marginal, customary,
# Nearest to over: forearm, campos, compensated, thayer, ericaceae, deducted, trace, consequently,
# Nearest to only: clinker, gradients, articulations, widowers, drain, innocent, spaces, encompass,
# Nearest to most: hrothgar, jute, contrastive, ile, condensates, hammered, duckling, antihydrogen,
# Nearest to american: tori, owl, aoraki, overdrive, warmest, soften, schneier, crashes,
# Nearest to new: rabinowitz, imhotep, existed, gorgon, muharram, phrygia, bakassi, hampered,
# Average loss at step 10000: 19.238718
# Average loss at step 20000: 16.982628
# Average loss at step 30000: 16.412551
# Average loss at step 40000: 15.746771
# Average loss at step 50000: 15.612175
# Nearest to have: has, had, having, contain, include, require, provide, consider,
# Nearest to after: before, during, following, despite, when, without, until, afterwards,
# Nearest to s: his, whose, isbn, our, their, gherkin, attlee, boredom,
# Nearest to many: several, some, various, certain, all, numerous, most, these,
# Nearest to all: various, many, several, some, nightlife, barrios, certain, these,
# Nearest to state: government, congress, superintendence, county, tintin, territory, giants, tristram,
# Nearest to during: before, in, after, since, throughout, despite, within, at,
# Nearest to it: he, she, this, there, always, burgos, pascal, jervis,
# Nearest to however: although, while, but, that, though, since, which, because,
# Nearest to world: referees, second, sank, region, smoky, sermons, blackadder, panic,
# Nearest to he: she, it, they, who, beeb, upbeat, weekday, machinima,
# Nearest to over: within, under, about, approximately, across, around, knud, polarized,
# Nearest to only: always, kensington, still, forgot, parent, hoffa, ambivalent, fake,
# Nearest to most: many, more, less, jet, especially, some, targ, particularly,
# Nearest to american: british, canadian, allure, descriptor, susa, australian, america, mercosur,
# Nearest to new: single, specific, separate, rentals, reluctant, timaeus, stochastic, transmitter,
# Average loss at step 60000: 15.180970
# Average loss at step 70000: 14.839050
# Average loss at step 80000: 14.680474
# Average loss at step 90000: 14.544752
# Average loss at step 100000: 13.650432
# Nearest to have: had, has, having, contain, require, represent, include, produce,
# Nearest to after: before, afterwards, without, following, despite, since, ternary, harbin,
# Nearest to s: his, my, whose, your, digger, its, kamal, isbn,
# Nearest to many: some, several, numerous, various, thousands, both, hundreds, all,
# Nearest to all: various, many, some, every, xxv, both, entirely, any,
# Nearest to state: government, institution, chicago, shamash, missouri, stanzas, states, catalana,
# Nearest to during: throughout, despite, in, until, since, at, involves, before,
# Nearest to it: she, he, this, there, everyone, still, coupon, linkages,
# Nearest to however: although, but, though, since, hence, while, that, because,
# Nearest to world: dresser, comically, division, panic, rite, masjid, europe, dial,
# Nearest to he: she, it, they, initially, segregated, who, briefly, beeb,
# Nearest to over: across, through, throughout, nearly, approximately, off, about, knud,
# Nearest to only: criminalized, always, first, actually, lowest, usually, last, rgermeister,
# Nearest to most: particularly, less, more, especially, many, best, some, first,
# Nearest to american: canadian, english, australian, british, dutch, irish, allure, scottish,
# Nearest to new: old, specific, veneer, modern, previous, btr, transmitter, sinbad,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
They are fairly similar!
